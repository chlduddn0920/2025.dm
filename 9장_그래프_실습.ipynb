# %% [markdown]
# <a href="https://colab.research.google.com/github/chlduddn0920/2025.dm/blob/main/9%EC%9E%A5_%EA%B7%B8%EB%9E%98%ED%94%84_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 쉬운 DFS (깊이 우선 탐색)
def dfs(graph, start):
    visited = []       # 방문한 노드들을 저장
    stack = [start]    # 다음에 방문할 노드를 담는 스택

    while stack:
        node = stack.pop()
        if node not in visited:
            print(node, end=' ')
            visited.append(node)
            # 인접 노드를 거꾸로 넣으면 사전순 탐색됨
            for neighbor in reversed(graph[node]):
                if neighbor not in visited:
                    stack.append(neighbor)
    return visited

# 예시 그래프
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

print("DFS 탐색 순서:")
dfs(graph, 'A')
# Out:
# DFS 탐색 순서:
# A B D E F C
# ['A', 'B', 'D', 'E', 'F', 'C']

# %%
from collections import deque

# 쉬운 BFS (너비 우선 탐색)
def bfs(graph, start):
    visited = []              # 방문한 노드
    queue = deque([start])    # 방문 예정 노드

    while queue:
        node = queue.popleft()
        if node not in visited:
            print(node, end=' ')
            visited.append(node)
            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)
    return visited

print("\nBFS 탐색 순서:")
bfs(graph, 'A')
# Out:
# BFS 탐색 순서:
# A B C D E F
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
from collections import deque

# 예시 그래프 (사람들 관계)
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

# -------------------------------
# DFS : 깊이 우선 탐색
# -------------------------------
def dfs(graph, start):
    visited = []
    stack = [start]
    print("DFS 탐색 순서:")

    while stack:
        node = stack.pop()
        if node not in visited:
            print(node, end=' ')
            visited.append(node)
            for neighbor in reversed(graph[node]):
                if neighbor not in visited:
                    stack.append(neighbor)
    print("\n")
    return visited

# -------------------------------
# BFS : 너비 우선 탐색
# -------------------------------
def bfs(graph, start):
    visited = []
    queue = deque([start])
    print("BFS 탐색 순서:")

    while queue:
        node = queue.popleft()
        if node not in visited:
            print(node, end=' ')
            visited.append(node)
            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)
    print("\n")
    return visited

# -------------------------------
# 감염 시뮬레이션 (BFS 2단계)
# -------------------------------
def infection_simulation(graph, start, max_step=2):
    queue = deque([(start, 0)])
    infected = {start}
    print(f"감염 시작: {start}")
    print(f"{max_step}단계까지 전염 경로:")

    while queue:
        node, step = queue.popleft()
        if step < max_step:
            for friend in graph[node]:
                if friend not in infected:
                    infected.add(friend)
                    print(f"{' ' * (step*2)}{node} → {friend} (단계 {step+1})")
                    queue.append((friend, step + 1))
    print("\n전체 감염자:", infected)
    return infected

# 실행 부분
dfs(graph, 'A')
bfs(graph, 'A')
infection_simulation(graph, 'A', max_step=2)
# Out:
# DFS 탐색 순서:
# A B D E F C
#
# BFS 탐색 순서:
# A B C D E F
#
# 감염 시작: A
# 2단계까지 전염 경로:
# A → B (단계 1)
# A → C (단계 1)
#   B → D (단계 2)
#   B → E (단계 2)
#   C → F (단계 2)
#
# 전체 감염자: {'A', 'D', 'E', 'B', 'C', 'F'}
# {'A', 'B', 'C', 'D', 'E', 'F'}

# %%
from collections import deque

# 3조 팀원 그래프 (예시 관계)
graph = {
    '이연우': ['이윤호', '최영우'],
    '이윤호': ['이연우', '구다은'],
    '최영우': ['이연우', '구다은'],
    '구다은': ['이윤호', '최영우']
}

# -------------------------------
# DFS : 깊이 우선 탐색
# -------------------------------
def dfs(graph, start):
    visited = []
    stack = [start]
    print("DFS 탐색 순서:")

    while stack:
        node = stack.pop()
        if node not in visited:
            print(node, end=' ')
            visited.append(node)
            for neighbor in reversed(graph[node]):
                if neighbor not in visited:
                    stack.append(neighbor)
    print("\n")
    return visited

# -------------------------------
# BFS : 너비 우선 탐색
# -------------------------------
def bfs(graph, start):
    visited = []
    queue = deque([start])
    print("BFS 탐색 순서:")

    while queue:
        node = queue.popleft()
        if node not in visited:
            print(node, end=' ')
            visited.append(node)
            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)
    print("\n")
    return visited

# -------------------------------
# 감염 시뮬레이션 (BFS 기반)
# -------------------------------
def infection_simulation(graph, start, max_step=2):
    queue = deque([(start, 0)])
    infected = {start}
    print(f"감염 시작: {start}")
    print(f"{max_step}단계까지 전염 경로:")

    while queue:
        node, step = queue.popleft()
        if step < max_step:
            for friend in graph[node]:
                if friend not in infected:
                    infected.add(friend)
                    print(f"{' ' * (step*2)}{node} → {friend} (단계 {step+1})")
                    queue.append((friend, step + 1))
    print("\n전체 감염자:", infected)
    return infected

# -------------------------------
# 실행
# -------------------------------
dfs(graph, '이연우')
bfs(graph, '이연우')
infection_simulation(graph, '이연우', max_step=2)
# Out:
# DFS 탐색 순서:
# 이연우 이윤호 구다은 최영우
#
# BFS 탐색 순서:
# 이연우 이윤호 최영우 구다은
#
# 감염 시작: 이연우
# 2단계까지 전염 경로:
# 이연우 → 이윤호 (단계 1)
# 이연우 → 최영우 (단계 1)
#   이윤호 → 구다은 (단계 2)
#
# 전체 감염자: {'최영우', '이연우', '이윤호', '구다은'}
# {'구다은', '이연우', '이윤호', '최영우'}

# %%
# ========================= 과제 메타 =========================
# 프롬프트(요약): "인접 리스트 그래프에서 DFS/BFS 탐색 순서와
#                 감염 시뮬레이션(거리 k 이내, 본인 제외)을 소/중/대 3케이스로 구현"
# 사용 AI 서비스: GPT-5 (ChatGPT)
# ============================================================

from collections import deque, defaultdict
import random

# ------------------------------------------------------------
# 공통 유틸
# ------------------------------------------------------------
def dfs(graph, start):
    order, visited, stack = [], set(), [start]
    while stack:
        node = stack.pop()
        if node in visited:
            continue
        visited.add(node)
        order.append(node)
        for nb in reversed(graph.get(node, [])):
            if nb not in visited:
                stack.append(nb)
    return order

def bfs(graph, start):
    order, visited, q = [], set([start]), deque([start])
    while q:
        cur = q.popleft()
        order.append(cur)
        for nb in graph.get(cur, []):
            if nb not in visited:
                visited.add(nb)
                q.append(nb)
    return order

def infection_within_k(graph, patient_zero, k=2):
    visited = {patient_zero: 0}
    q = deque([patient_zero])
    by_level = defaultdict(list)

    while q:
        cur = q.popleft()
        d = visited[cur]
        if d == k:
            continue
        for nb in graph.get(cur, []):
            if nb not in visited:
                visited[nb] = d + 1
                q.append(nb)
                if visited[nb] >= 1:
                    by_level[visited[nb]].append(nb)
    for lvl in by_level:
        by_level[lvl].sort()
    return dict(sorted(by_level.items()))

def print_case(title, graph, start, k):
    print(f"\n================ {title} ================")
    print("[그래프(인접 리스트)]")
    for u in sorted(graph):
        print(f"  {u}: {graph[u]}")
    print("\n[DFS 순서]")
    print("  " + " -> ".join(dfs(graph, start)))
    print("[BFS 순서]")
    print("  " + " -> ".join(bfs(graph, start)))
    by_level = infection_within_k(graph, start, k=k)
    print(f"\n[감염 시뮬레이션] 환자0={start}, 최대 {k}단계")
    if not by_level:
        print("  (감염 확산 없음)")
    else:
        total = 0
        for lvl in sorted(by_level):
            nodes = by_level[lvl]
            total += len(nodes)
            print(f"  - {lvl}단계({len(nodes)}명): " + ", ".join(nodes))
        print(f"  ▶ 총 감염자 수(본인 제외): {total}")

# ------------------------------------------------------------
# [소] (노드 8, k=2)
# ------------------------------------------------------------
graph_small = {
    '이연우': ['이윤호', '최영우', '박지윤'],
    '이윤호': ['이연우', '구다은', '정민'],
    '최영우': ['이연우', '구다은', '김하늘'],
    '구다은': ['이윤호', '최영우', '전우성'],
    '박지윤': ['이연우', '전우성'],
    '전우성': ['박지윤', '구다은'],
    '정민': ['이윤호'],
    '김하늘': ['최영우'],
}
start_small = '이연우'
print_case("소형 케이스 (노드≈8, k=2)", graph_small, start_small, k=2)

# ------------------------------------------------------------
# [중] (노드 50, k=5)
# ------------------------------------------------------------
def build_medium_graph(n=50, seed=11):
    random.seed(seed)
    adj = {f"N{i}": [] for i in range(n)}
    for i in range(n-1):
        a, b = f"N{i}", f"N{i+1}"
        adj[a].append(b); adj[b].append(a)
    for _ in range(n):
        u, v = random.randrange(n), random.randrange(n)
        if u != v:
            a, b = f"N{min(u,v)}", f"N{max(u,v)}"
            if b not in adj[a]:
                adj[a].append(b); adj[b].append(a)
    for k in adj:
        adj[k] = sorted(adj[k])
    return adj

graph_med = build_medium_graph(50, seed=11)
start_med = "N0"
print_case("중형 케이스 (노드≈50, k=5)", graph_med, start_med, k=5)

# ------------------------------------------------------------
# [대] (노드 200, k=15)
# ------------------------------------------------------------
def build_grid_graph(rows=10, cols=20):
    adj = {}
    for r in range(rows):
        for c in range(cols):
            u = f"G_{r}_{c}"
            neigh = []
            if r+1 < rows: neigh.append(f"G_{r+1}_{c}")
            if c+1 < cols: neigh.append(f"G_{r}_{c+1}")
            if r-1 >= 0:   neigh.append(f"G_{r-1}_{c}")
            if c-1 >= 0:   neigh.append(f"G_{r}_{c-1}")
            adj[u] = neigh
    return adj

graph_big = build_grid_graph(10, 20)  # 10x20=200
start_big = "G_0_0"
print(f"\n================ 대형 케이스 (노드≈200, k=15) ================")
print(f"[그래프 요약] 시작노드={start_big}, 이웃={graph_big[start_big][:4]} ...")
dfs_big = dfs(graph_big, start_big)[:20]
bfs_big = bfs(graph_big, start_big)[:20]
print("[DFS 순서(앞 20개)]")
print("  " + " -> ".join(dfs_big) + " -> ...")
print("[BFS 순서(앞 20개)]")
print("  " + " -> ".join(bfs_big) + " -> ...")

by_level_big = infection_within_k(graph_big, start_big, k=15)
for lvl in range(1, 6):
    nodes = by_level_big.get(lvl, [])
    if nodes:
        preview = ", ".join(nodes[:10])
        print(f"  - {lvl}단계({len(nodes)}명): {preview}{' ...' if len(nodes)>10 else ''}")
# Out:
# ================ 소형 케이스 (노드≈8, k=2) ================
# [그래프(인접 리스트)]
#   구다은: ['이윤호', '최영우', '전우성']
#   김하늘: ['최영우']
#   박지윤: ['이연우', '전우성']
#   이연우: ['이윤호', '최영우', '박지윤']
#   이윤호: ['이연우', '구다은', '정민']
#   전우성: ['박지윤', '구다은']
#   정민: ['이윤호']
#   최영우: ['이연우', '구다은', '김하늘']
#
# [DFS 순서]
#   이연우 -> 이윤호 -> 구다은 -> 최영우 -> 김하늘 -> 전우성 -> 박지윤 -> 정민
# [BFS 순서]
#   이연우 -> 이윤호 -> 최영우 -> 박지윤 -> 구다은 -> 정민 -> 김하늘 -> 전우성
#
# [감염 시뮬레이션] 환자0=이연우, 최대 2단계
#   - 1단계(3명): 박지윤, 이윤호, 최영우
#   - 2단계(4명): 구다은, 김하늘, 전우성, 정민
#   ▶ 총 감염자 수(본인 제외): 7
#
# ================ 중형 케이스 (노드≈50, k=5) ================
# [그래프(인접 리스트)]
#   N0: ['N1', 'N13', 'N33', 'N42']
#   N1: ['N0', 'N2', 'N4', 'N43', 'N49']
#   N10: ['N11', 'N39', 'N9']
#   N11: ['N10', 'N12', 'N32', 'N39']
#   N12: ['N11', 'N13', 'N2', 'N33', 'N37', 'N49']
#   N13: ['N0', 'N12', 'N14', 'N3']
#   N14: ['N13', 'N15', 'N40', 'N48']
#   N15: ['N14', 'N16', 'N38']
#   N16: ['N15', 'N17', 'N20']
#   N17: ['N16', 'N18', 'N41', 'N43']
#   N18: ['N17', 'N19', 'N31', 'N32', 'N6']
#   N19: ['N18', 'N20', 'N21', 'N9']
#   N2: ['N1', 'N12', 'N3', 'N38']
#   N20: ['N16', 'N19', 'N21', 'N29']
#   N21: ['N19', 'N20', 'N22', 'N5']
#   N22: ['N21', 'N23']
#   N23: ['N22', 'N24']
#   N24: ['N23', 'N25', 'N30', 'N4']
#   N25: ['N24', 'N26', 'N28', 'N45', 'N6']
#   N26: ['N25', 'N27', 'N35', 'N4']
#   N27: ['N26', 'N28']
#   N28: ['N25', 'N27', 'N29', 'N32', 'N35', 'N37', 'N6']
#   N29: ['N20', 'N28', 'N30', 'N49', 'N5']
#   N3: ['N13', 'N2', 'N4']
#   N30: ['N24', 'N29', 'N31', 'N40']
#   N31: ['N18', 'N30', 'N32']
#   N32: ['N11', 'N18', 'N28', 'N31', 'N33']
#   N33: ['N0', 'N12', 'N32', 'N34']
#   N34: ['N33', 'N35', 'N5']
#   N35: ['N26', 'N28', 'N34', 'N36']
#   N36: ['N35', 'N37', 'N40', 'N49']
#   N37: ['N12', 'N28', 'N36', 'N38']
#   N38: ['N15', 'N2', 'N37', 'N39']
#   N39: ['N10', 'N11', 'N38', 'N40', 'N41']
#   N4: ['N1', 'N24', 'N26', 'N3', 'N5']
#   N40: ['N14', 'N30', 'N36', 'N39', 'N41', 'N44']
#   N41: ['N17', 'N39', 'N40', 'N42', 'N47']
#   N42: ['N0', 'N41', 'N43']
#   N43: ['N1', 'N17', 'N42', 'N44']
#   N44: ['N40', 'N43', 'N45']
#   N45: ['N25', 'N44', 'N46', 'N5']
#   N46: ['N45', 'N47']
#   N47: ['N41', 'N46', 'N48']
#   N48: ['N14', 'N47', 'N49']
#   N49: ['N1', 'N12', 'N29', 'N36', 'N48']
#   N5: ['N21', 'N29', 'N34', 'N4', 'N45', 'N6']
#   N6: ['N18', 'N25', 'N28', 'N5', 'N7']
#   N7: ['N6', 'N8']
#   N8: ['N7', 'N9']
#   N9: ['N10', 'N19', 'N8']
#
# [DFS 순서]
#   N0 -> N1 -> N2 -> N12 -> N11 -> N10 -> N39 -> N38 -> N15 -> N14 -> N13 -> N3 -> N4 -> N24 -> N23 -> N22 -> N21 -> N19 -> N18 -> N17 -> N16 -> N20 -> N29 -> N28 -> N25 -> N26 -> N27 -> N35 -> N34 -> N33 -> N32 -> N31 -> N30 -> N40 -> N36 -> N37 -> N49 -> N48 -> N47 -> N41 -> N42 -> N43 -> N44 -> N45 -> N46 -> N5 -> N6 -> N7 -> N8 -> N9
# [BFS 순서]
#   N0 -> N1 -> N13 -> N33 -> N42 -> N2 -> N4 -> N43 -> N49 -> N12 -> N14 -> N3 -> N32 -> N34 -> N41 -> N38 -> N24 -> N26 -> N5 -> N17 -> N44 -> N29 -> N36 -> N48 -> N11 -> N37 -> N15 -> N40 -> N18 -> N28 -> N31 -> N35 -> N39 -> N47 -> N23 -> N25 -> N30 -> N27 -> N21 -> N45 -> N6 -> N16 -> N20 -> N10 -> N19 -> N46 -> N22 -> N7 -> N9 -> N8
#
# [감염 시뮬레이션] 환자0=N0, 최대 5단계
#   - 1단계(4명): N1, N13, N33, N42
#   - 2단계(10명): N12, N14, N2, N3, N32, N34, N4, N41, N43, N49
#   - 3단계(19명): N11, N15, N17, N18, N24, N26, N28, N29, N31, N35, N36, N37, N38, N39, N40, N44, N47, N48, N5
#   - 4단계(12명): N10, N16, N19, N20, N21, N23, N25, N27, N30, N45, N46, N6
#   - 5단계(3명): N22, N7, N9
#   ▶ 총 감염자 수(본인 제외): 48
#
# ================ 대형 케이스 (노드≈200, k=15) ================
# [그래프 요약] 시작노드=G_0_0, 이웃=['G_1_0', 'G_0_1'] ...
# [DFS 순서(앞 20개)]
#   G_0_0 -> G_1_0 -> G_2_0 -> G_3_0 -> G_4_0 -> G_5_0 -> G_6_0 -> G_7_0 -> G_8_0 -> G_9_0 -> G_9_1 -> G_9_2 -> G_9_3 -> G_9_4 -> G_9_5 -> G_9_6 -> G_9_7 -> G_9_8 -> G_9_9 -> G_9_10 -> ...
# [BFS 순서(앞 20개)]
#   G_0_0 -> G_1_0 -> G_0_1 -> G_2_0 -> G_1_1 -> G_0_2 -> G_3_0 -> G_2_1 -> G_1_2 -> G_0_3 -> G_4_0 -> G_3_1 -> G_2_2 -> G_1_3 -> G_0_4 -> G_5_0 -> G_4_1 -> G_3_2 -> G_2_3 -> G_1_4 -> ...
#   - 1단계(2명): G_0_1, G_1_0
#   - 2단계(3명): G_0_2, G_1_1, G_2_0
#   - 3단계(4명): G_0_3, G_1_2, G_2_1, G_3_0
#   - 4단계(5명): G_0_4, G_1_3, G_2_2, G_3_1, G_4_0
#   - 5단계(6명): G_0_5, G_1_4, G_2_3, G_3_2, G_4_1, G_5_0
